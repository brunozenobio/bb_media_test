# %%
import json
import pandas as pd

with open("./database/series.json","r") as series:
    datos = json.load(series)

datos[5:10]

df_movies = pd.read_csv("./database/movies.csv")
df_channels = pd.read_csv("./database/channels.csv")

# %%
df_movies
# Out:
#                                                   title               genre  \
# 0     Momentos que Cambiaron la historia - Valor inu...         Documentary
# 1                    Tastil, la majestuoso y misteriosa         Documentary
# 2                             Lo Mejor De Lo Mejor 2019         Documentary
# 3                                       Yo Soy La Salsa         Documentary
# 4                     Sparks, La Historia de Ken Sparks         Documentary
# ...                                                 ...                 ...
# 1584                                       Poseidón Rex    Sci-Fi & Fantasy
# 1585                              El Dador de Recuerdos    Sci-Fi & Fantasy
# 1586                               El imperio prohibido  Action & Adventure
# 1587                                        Planetarium    Sci-Fi & Fantasy
# 1588                                    Autodestrucción    Sci-Fi & Fantasy
#
#      classification    duration  \
# 0                 G      47 min
# 1             TV-PG      46 min
# 2              TV-G  1hr 22 min
# 3               NaN  1hr 20 min
# 4                PG  1hr 30 min
# ...             ...         ...
# 1584          TV-MA  1hr 19 min
# 1585             PG  1hr 37 min
# 1586             PG  1hr 51 min
# 1587          PG-13  1hr 48 min
# 1588              R  1hr 31 min
#
#                                                synopsis  \
# 0     Para el verano de 1944, los dieciocho kilómetr...
# 1     Muy cerca de la cordillera de Los Andes, a cas...
# 2     La más original e innovadora lista de eventos ...
# 3     Más que un género musical, la salsa fue un mov...
# 4     Durante 46 años, Ken Sparks dedicó su vida, a ...
# ...                                                 ...
# 1584  Cuenta como una pequeña isla, cerca de la cost...
# 1585  Cuenta la historia de un mundo perfecto en el ...
# 1586  Principios del siglo 18. El cartógrafo Cartogr...
# 1587  Planetarium" sigue el viaje de hermanas que se...
# 1588  Autodestrucción es una versión de un mundo fut...
#
#                                                     url
# 0     https://pluto.tv/on-demand/movies/639b8da24da5...
# 1     https://pluto.tv/on-demand/movies/5fdbbe8c0983...
# 2     https://pluto.tv/on-demand/movies/5e2620153a83...
# 3     https://pluto.tv/on-demand/movies/5e609aef4698...
# 4     https://pluto.tv/on-demand/movies/65c39557ecf2...
# ...                                                 ...
# 1584  https://pluto.tv/on-demand/movies/603e621a0496...
# 1585  https://pluto.tv/on-demand/movies/5f7b86f0e4b5...
# 1586  https://pluto.tv/on-demand/movies/65cfb7bf6ef4...
# 1587  https://pluto.tv/on-demand/movies/65c3aea6b65b...
# 1588  https://pluto.tv/on-demand/movies/5f7b86cbe4b5...
#
# [1589 rows x 6 columns]

# %%
print(f"Hay un total de {len(df_movies)} peliculas y un total de {len(df_movies["genre"].unique())} generos")
# Out:
# Hay un total de 1589 peliculas y un total de 22 generos

# %%
df_channels.sample(5)
# Out:
#                      Nombre_Canal  \
# 30         Pluto TV  Nuestro Cine
# 37  Pluto TV Dramas Coreanos Teen
# 52        Pluto TV Series Latinas
# 8        Sin Tetas No Hay Paraíso
# 4                     MTV Reality
#
#                                             Url_Canal
# 30  https://pluto.tv/live-tv/6474a86917f5e100089a0...
# 37  https://pluto.tv/live-tv/63eb95baa99571000898a...
# 52  https://pluto.tv/live-tv/63211ba9cad976000794f...
# 8   https://pluto.tv/live-tv/639751f81a36b400072b8...
# 4   https://pluto.tv/live-tv/5ffe17e3d765170007c3a...

# %%
print(f"Hay un total de {len(df_channels)} canales ")
# Out:
# Hay un total de 53 canales

# %%
df_serie = pd.DataFrame(columns=['title',"genre","classification","synopsis","temporadas"
                                 ,"url"])
for serie in datos:
    df_serie.loc[len(df_serie)] = [serie["title"],serie["genre"],serie["classification"],serie["synopsis"],len(serie["seasons"]),serie["url"]]
    

df_serie
# Out:
#                           title               genre classification  \
# 0                         Daria              Comedy          TV-PG
# 1      Sin tetas no hay paraíso          Telenovela          TV-PG
# 2                      Inuyasha               Anime          TV-14
# 3         La Familia del Barrio              Comedy          TV-14
# 4              Freaks and Geeks              Comedy          PG-13
# ..                          ...                 ...            ...
# 206                       Flood  Action & Adventure          TV-14
# 207                   El Asalto  Action & Adventure          PG-13
# 208  Final days of planet earth  Action & Adventure          TV-14
# 209                     Tornado    Sci-Fi & Fantasy          TV-14
# 210               ¡Han llegado!            Thriller          PG-13
#
#                                               synopsis  temporadas  \
# 0    Daria Morgendorfferr es una chica inteligente ...           5
# 1    Unos senos grandes son la puerta de entrada a ...           1
# 2    Aome Higurashi conoce a Inuyasha, medio demoni...           7
# 3    La serie relata las desventuras de una familia...           5
# 4    La experiencia universal de la adolescencia qu...           1
# ..                                                 ...         ...
# 206  Cuando una tormenta embravecida desata una mar...           1
# 207  Un robo a un banco entrelaza las vidas del dir...           1
# 208  Un arqueólogo y una entomóloga que investiga u...           1
# 209  Durante el verano más caluroso en años de Berl...           1
# 210  El astrónomo de radio Zane Zaminsky cree que h...           1
#
#                                                    url
# 0    https://pluto.tv/on-demand/series/5e20986b3708...
# 1    https://pluto.tv/on-demand/series/5edfffd86e00...
# 2    https://pluto.tv/on-demand/series/64a83d8df56d...
# 3    https://pluto.tv/on-demand/series/5f1756eb6ebd...
# 4    https://pluto.tv/on-demand/series/5e6178085c1e...
# ..                                                 ...
# 206  https://pluto.tv/on-demand/series/5fa45f396492...
# 207  https://pluto.tv/on-demand/series/63ce8bdbe8fb...
# 208  https://pluto.tv/on-demand/series/5fb2f4de93fb...
# 209  https://pluto.tv/on-demand/series/60468c2c601b...
# 210  https://pluto.tv/on-demand/series/65cfab149255...
#
# [211 rows x 6 columns]

# %%
print(f"Hay un total de {len(df_serie)} series con {len(df_serie["genre"].unique())} generos")


max_temporadas = int(df_serie["temporadas"].idxmax())
min_temporadas = int(df_serie["temporadas"].idxmin())
print(f"La serie con mayor cantidad de temporadas es {df_serie.iloc[max_temporadas]["title"]} con {df_serie.iloc[max_temporadas]["temporadas"]} temporadas" )
# Out:
# Hay un total de 211 series con 18 generos
# La serie con mayor cantidad de temporadas es South Park con 25 temporadas

# %%
episodios = pd.DataFrame(columns=['title', 'season', 'number_of_episodes'])

for serie in datos:
    title = serie["title"]  
    for temporada in serie["seasons"]:
        season = temporada["season"]  
        number_of_episodes = len(temporada["episodes"])

        nueva_fila = pd.DataFrame({
            'title': [title],
            'season': [season],
            'number_of_episodes': [number_of_episodes]
        })

        episodios = pd.concat([episodios, nueva_fila], ignore_index=True)


episodios
# Out:
#                           title    season number_of_episodes
# 0                         Daria  Season 1                 13
# 1                         Daria  Season 2                 13
# 2                         Daria  Season 3                 13
# 3                         Daria  Season 4                 13
# 4                         Daria  Season 5                 13
# ..                          ...       ...                ...
# 407                       Flood  Season 1                  2
# 408                   El Asalto  Season 1                  3
# 409  Final days of planet earth  Season 1                  2
# 410                     Tornado  Season 1                  2
# 411               ¡Han llegado!  Season 1                  1
#
# [412 rows x 3 columns]
